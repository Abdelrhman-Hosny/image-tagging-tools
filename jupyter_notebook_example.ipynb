# %% [markdown]
# # Mount Google Drive
#
# Mount your google drive to be used for storing the storing the dataset into it (optional to save datasets on mega to it) and also for saving the results in the drive.

# %%
from google.colab import drive
drive.mount._DEBUG = False
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Move Dataset from Mega to Drive
#
# Move the file with the provided link (Provide your username and password if it's not a public link) to your google drive already mounted before in the previous step.

# %% [markdown]
# ### Install Mega

# %%
import sys, os, urllib.request
import time
import subprocess
import contextlib
from IPython.display import clear_output
from functools import wraps
import errno
import os
import signal
import subprocess
import shlex
import glob

HOME = os.path.expanduser("~")
if not os.path.exists(f"{HOME}/.ipython/ocr.py"):
    hCode = "https://raw.githubusercontent.com/biplobsd/" \
                "OneClickRun/master/res/ocr.py"
    urllib.request.urlretrieve(hCode, f"{HOME}/.ipython/ocr.py")

from ocr import (
    runSh,
    loadingAn,
)

if not os.path.exists("/usr/bin/mega-cmd"):
    loadingAn()
    print("Installing MEGA ...")
    runSh('sudo apt-get -y update')
    runSh('sudo apt-get -y install libmms0 libc-ares2 libc6 libcrypto++6 libgcc1 libmediainfo0v5 libpcre3 libpcrecpp0v5 libssl1.1 libstdc++6 libzen0v5 zlib1g apt-transport-https')
    runSh('sudo curl -sL -o /var/cache/apt/archives/MEGAcmd.deb https://mega.nz/linux/MEGAsync/Debian_9.0/amd64/megacmd-Debian_9.0_amd64.deb', output=True)
    runSh('sudo dpkg -i /var/cache/apt/archives/MEGAcmd.deb', output=True)
    print("MEGA is installed.")
    clear_output()

# %% [markdown]
# ### provide URL and Mega ID
#
# Add the URL to fetch from Mega, and the username and password for those files if it wasn't a public URL and to use the pro mega quota if you have a pro account.

# %%
USERNAME = ""  
PASSWORD = "" 
TAGGED_DATASET_URL = "https://mega.nz/file/Ec5V1DKK#AwsUvEbDe-izExphB4SYRS9bP2LtyGBftVJM9AJO_Wg"
OTHER_DATASET_URL  = "https://mega.nz/file/MNo0ABSB#8rDqevxdQmtaNFKjQ3RS9v2pF-jL8xzmM9LLxIfAhG0"
OUTPUT_PATH = ""

# %%
# Unix, Windows and old Macintosh end-of-line
newlines = ['\n', '\r\n', '\r']

def latest_file(folder):
  list_of_files = glob.glob(f'{folder}/*') # * means all 
  latest_file = max(list_of_files, key=os.path.getctime)
  return latest_file

def unbuffered(proc, stream='stdout'):
    stream = getattr(proc, stream)
    with contextlib.closing(stream):
        while True:
            out = []
            last = stream.read(1)
            # Don't loop forever
            if last == '' and proc.poll() is not None:
                break
            while last not in newlines:
                # Don't loop forever
                if last == '' and proc.poll() is not None:
                    break
                out.append(last)
                last = stream.read(1)
            out = ''.join(out)
            yield out


def transfare(url):
    import codecs
    decoder = codecs.getincrementaldecoder("UTF-8")()
    cmd = ["mega-get", url, OUTPUT_PATH]
    proc = subprocess.Popen(
        cmd,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        # Make all end-of-lines '\n'
        universal_newlines=True,
    )
    for line in unbuffered(proc):
        print(line)
        
if not OUTPUT_PATH:
  os.makedirs("downloads", exist_ok=True)
  OUTPUT_PATH = "downloads"


class TimeoutError(Exception):
    pass

def timeout(seconds=10, error_message=os.strerror(errno.ETIME)):
    def decorator(func):
        def _handle_timeout(signum, frame):
            raise TimeoutError(error_message)

        def wrapper(*args, **kwargs):
            signal.signal(signal.SIGALRM, _handle_timeout)
            signal.alarm(seconds)
            try:
                result = func(*args, **kwargs)
            finally:
                signal.alarm(0)
            return result

        return wraps(func)(wrapper)

    return decorator


@timeout(10)
def runShT(args):
    return runSh(args, output=True)

def login(): 
    runShT(f"mega-login {USERNAME} {PASSWORD}")
    
if not (USERNAME == "" or PASSWORD == ""):
    try:
        login()
    except TimeoutError:
        runSh('mega-whoami', output=True)
else:
    print("Please Input your Mega IDs.")

transfare(TAGGED_DATASET_URL)
tagged_dataset_path = latest_file('./downloads')
transfare(OTHER_DATASET_URL)
other_dataset_path = latest_file('./downloads')
# Out:
# Please Input your Mega IDs.
# [Initiating MEGAcmd server in background. Log: /root/.megaCmd/megacmdserver.log]
# TRANSFERRING ||#........................................||(1/1236 MB:   0.14 %)
# TRANSFERRING ||#........................................||(2/1236 MB:   0.20 %)
# TRANSFERRING ||#........................................||(3/1236 MB:   0.29 %)
# TRANSFERRING ||#........................................||(5/1236 MB:   0.43 %)
# TRANSFERRING ||#........................................||(7/1236 MB:   0.62 %)
# TRANSFERRING ||#.......................................||(11/1236 MB:   0.90 %)
# TRANSFERRING ||#.......................................||(16/1236 MB:   1.31 %)
# TRANSFERRING ||#.......................................||(23/1236 MB:   1.89 %)
# TRANSFERRING ||#.......................................||(29/1236 MB:   2.35 %)
# TRANSFERRING ||##......................................||(36/1236 MB:   2.93 %)
# TRANSFERRING ||##......................................||(42/1236 MB:   3.41 %)
# TRANSFERRING ||##......................................||(49/1236 MB:   3.97 %)
# TRANSFERRING ||##......................................||(55/1236 MB:   4.48 %)
# TRANSFERRING ||###.....................................||(62/1236 MB:   5.02 %)
# TRANSFERRING ||###.....................................||(63/1236 MB:   5.13 %)
# TRANSFERRING ||#.......................................||(16/1236 MB:   1.29 %)
# TRANSFERRING ||##......................................||(47/1236 MB:   3.84 %)
# TRANSFERRING ||###.....................................||(63/1236 MB:   5.14 %)
# TRANSFERRING ||###.....................................||(63/1236 MB:   5.14 %)
# TRANSFERRING ||###.....................................||(64/1236 MB:   5.21 %)
# TRANSFERRING ||###.....................................||(66/1236 MB:   5.35 %)
# TRANSFERRING ||###.....................................||(70/1236 MB:   5.74 %)
# TRANSFERRING ||###.....................................||(77/1236 MB:   6.26 %)
# TRANSFERRING ||###.....................................||(83/1236 MB:   6.79 %)
# TRANSFERRING ||###.....................................||(90/1236 MB:   7.32 %)
# TRANSFERRING ||####....................................||(96/1236 MB:   7.82 %)
# TRANSFERRING ||####...................................||(103/1236 MB:   8.36 %)
# TRANSFERRING ||####...................................||(109/1236 MB:   8.87 %)
# TRANSFERRING ||####...................................||(116/1236 MB:   9.40 %)
# TRANSFERRING ||####...................................||(121/1236 MB:   9.83 %)
# TRANSFERRING ||####...................................||(126/1236 MB:  10.21 %)
# TRANSFERRING ||####...................................||(111/1236 MB:   9.02 %)
# TRANSFERRING ||####...................................||(111/1236 MB:   9.02 %)
# TRANSFERRING ||#####..................................||(127/1236 MB:  10.31 %)
# TRANSFERRING ||#####..................................||(128/1236 MB:  10.37 %)
# TRANSFERRING ||#####..................................||(129/1236 MB:  10.46 %)
# TRANSFERRING ||#####..................................||(131/1236 MB:  10.61 %)
# TRANSFERRING ||##.......................................||(46/987 MB:   4.71 %)
# TRANSFERRING ||##.......................................||(47/987 MB:   4.85 %)
# TRANSFERRING ||###......................................||(48/987 MB:   4.89 %)
# TRANSFERRING ||###......................................||(53/987 MB:   5.44 %)
# TRANSFERRING ||###......................................||(57/987 MB:   5.86 %)
# TRANSFERRING ||###......................................||(60/987 MB:   6.14 %)
# TRANSFERRING ||###......................................||(63/987 MB:   6.45 %)
# TRANSFERRING ||###......................................||(66/987 MB:   6.72 %)
# TRANSFERRING ||###......................................||(68/987 MB:   6.98 %)
# TRANSFERRING ||##.......................................||(47/987 MB:   4.85 %)
# TRANSFERRING ||###......................................||(49/987 MB:   5.03 %)
# TRANSFERRING ||####.....................................||(73/987 MB:   7.43 %)
# TRANSFERRING ||####.....................................||(74/987 MB:   7.54 %)
# TRANSFERRING ||####.....................................||(75/987 MB:   7.62 %)
# TRANSFERRING ||####.....................................||(77/987 MB:   7.90 %)
# TRANSFERRING ||####.....................................||(81/987 MB:   8.26 %)
# TRANSFERRING ||####.....................................||(84/987 MB:   8.53 %)
# TRANSFERRING ||####.....................................||(87/987 MB:   8.87 %)
# TRANSFERRING ||####.....................................||(88/987 MB:   9.00 %)
# TRANSFERRING ||####.....................................||(90/987 MB:   9.16 %)
# TRANSFERRING ||####.....................................||(92/987 MB:   9.36 %)
# TRANSFERRING ||####.....................................||(93/987 MB:   9.52 %)
# TRANSFERRING ||####.....................................||(94/987 MB:   9.54 %)
# TRANSFERRING ||####.....................................||(96/987 MB:   9.75 %)
# TRANSFERRING ||#####....................................||(99/987 MB:  10.05 %)
# TRANSFERRING ||#####...................................||(101/987 MB:  10.29 %)
# TRANSFERRING ||#####...................................||(102/987 MB:  10.41 %)
# TRANSFERRING ||#####...................................||(103/987 MB:  10.47 %)
# TRANSFERRING ||#####...................................||(103/987 MB:  10.49 %)
# TRANSFERRING ||#####...................................||(104/987 MB:  10.62 %)
# TRANSFERRING ||#####...................................||(105/987 MB:  10.64 %)
# TRANSFERRING ||#####...................................||(106/987 MB:  10.78 %)
# TRANSFERRING ||#####...................................||(107/987 MB:  10.88 %)
# TRANSFERRING ||#####...................................||(107/987 MB:  10.89 %)
# TRANSFERRING ||#####...................................||(109/987 MB:  11.08 %)
# TRANSFERRING ||#####...................................||(109/987 MB:  11.11 %)
# TRANSFERRING ||#####...................................||(109/987 MB:  11.14 %)
# TRANSFERRING ||#####...................................||(110/987 MB:  11.16 %)
# TRANSFERRING ||#####...................................||(110/987 MB:  11.16 %)
# TRANSFERRING ||#####...................................||(110/987 MB:  11.16 %)
# TRANSFERRING ||#####...................................||(110/987 MB:  11.16 %)
# TRANSFERRING ||#####...................................||(110/987 MB:  11.17 %)
# TRANSFERRING ||#####...................................||(110/987 MB:  11.20 %)
# TRANSFERRING ||#####...................................||(110/987 MB:  11.22 %)
# TRANSFERRING ||#####...................................||(111/987 MB:  11.25 %)
# TRANSFERRING ||#####...................................||(111/987 MB:  11.28 %)
# TRANSFERRING ||#####...................................||(111/987 MB:  11.30 %)
# TRANSFERRING ||#####...................................||(111/987 MB:  11.31 %)
# TRANSFERRING ||#####...................................||(111/987 MB:  11.32 %)
# TRANSFERRING ||#####...................................||(111/987 MB:  11.34 %)
# TRANSFERRING ||#####...................................||(112/987 MB:  11.36 %)
# TRANSFERRING ||#####...................................||(112/987 MB:  11.37 %)
# TRANSFERRING ||#####...................................||(112/987 MB:  11.39 %)
# TRANSFERRING ||#####...................................||(112/987 MB:  11.40 %)
# TRANSFERRING ||#####...................................||(112/987 MB:  11.41 %)
# TRANSFERRING ||#####...................................||(112/987 MB:  11.43 %)
# TRANSFERRING ||#####...................................||(112/987 MB:  11.44 %)
# TRANSFERRING ||#####...................................||(113/987 MB:  11.47 %)
# TRANSFERRING ||#####...................................||(113/987 MB:  11.48 %)
# TRANSFERRING ||#####...................................||(113/987 MB:  11.50 %)
# TRANSFERRING ||#####...................................||(113/987 MB:  11.51 %)
# TRANSFERRING ||#####...................................||(112/987 MB:  11.44 %)
# TRANSFERRING ||#####...................................||(112/987 MB:  11.44 %)
# TRANSFERRING ||#####...................................||(114/987 MB:  11.55 %)
# TRANSFERRING ||#####...................................||(115/987 MB:  11.74 %)
# TRANSFERRING ||#####...................................||(118/987 MB:  12.05 %)
# TRANSFERRING ||#####...................................||(120/987 MB:  12.17 %)
# TRANSFERRING ||#####...................................||(120/987 MB:  12.23 %)
# TRANSFERRING ||#####...................................||(120/987 MB:  12.24 %)
# TRANSFERRING ||#####...................................||(120/987 MB:  12.25 %)
# TRANSFERRING ||#####...................................||(121/987 MB:  12.27 %)
# TRANSFERRING ||#####...................................||(122/987 MB:  12.43 %)
# TRANSFERRING ||#####...................................||(123/987 MB:  12.49 %)
# TRANSFERRING ||######..................................||(126/987 MB:  12.77 %)
# TRANSFERRING ||######..................................||(127/987 MB:  12.93 %)
# TRANSFERRING ||######..................................||(127/987 MB:  12.95 %)
# TRANSFERRING ||######..................................||(128/987 MB:  12.98 %)
# TRANSFERRING ||######..................................||(128/987 MB:  13.00 %)
# TRANSFERRING ||######..................................||(128/987 MB:  13.03 %)
# TRANSFERRING ||######..................................||(128/987 MB:  13.07 %)
# TRANSFERRING ||######..................................||(129/987 MB:  13.11 %)
# TRANSFERRING ||######..................................||(129/987 MB:  13.16 %)
# TRANSFERRING ||######..................................||(131/987 MB:  13.32 %)
# TRANSFERRING ||######..................................||(133/987 MB:  13.54 %)
# TRANSFERRING ||######..................................||(135/987 MB:  13.68 %)
# TRANSFERRING ||######..................................||(137/987 MB:  13.92 %)
# TRANSFERRING ||######..................................||(137/987 MB:  13.94 %)
# TRANSFERRING ||######..................................||(137/987 MB:  13.95 %)
# TRANSFERRING ||######..................................||(137/987 MB:  13.98 %)
# TRANSFERRING ||######..................................||(139/987 MB:  14.12 %)
# TRANSFERRING ||######..................................||(140/987 MB:  14.25 %)
# TRANSFERRING ||######..................................||(141/987 MB:  14.36 %)
# TRANSFERRING ||######..................................||(142/987 MB:  14.44 %)
# TRANSFERRING ||######..................................||(142/987 MB:  14.45 %)
# TRANSFERRING ||######..................................||(142/987 MB:  14.46 %)
# TRANSFERRING ||######..................................||(142/987 MB:  14.47 %)
# TRANSFERRING ||######..................................||(142/987 MB:  14.48 %)
# TRANSFERRING ||######..................................||(143/987 MB:  14.49 %)
# TRANSFERRING ||######..................................||(143/987 MB:  14.50 %)
# TRANSFERRING ||######..................................||(143/987 MB:  14.51 %)
# TRANSFERRING ||######..................................||(143/987 MB:  14.52 %)
# TRANSFERRING ||######..................................||(143/987 MB:  14.53 %)
# TRANSFERRING ||######..................................||(143/987 MB:  14.54 %)
# TRANSFERRING ||######..................................||(143/987 MB:  14.55 %)
# TRANSFERRING ||######..................................||(143/987 MB:  14.56 %)
# TRANSFERRING ||######..................................||(143/987 MB:  14.57 %)
# TRANSFERRING ||######..................................||(143/987 MB:  14.58 %)
# TRANSFERRING ||######..................................||(144/987 MB:  14.60 %)
# TRANSFERRING ||######..................................||(144/987 MB:  14.61 %)
# TRANSFERRING ||######..................................||(144/987 MB:  14.62 %)
# TRANSFERRING ||######..................................||(144/987 MB:  14.63 %)
# TRANSFERRING ||######..................................||(144/987 MB:  14.64 %)
# TRANSFERRING ||######..................................||(144/987 MB:  14.65 %)
# TRANSFERRING ||######..................................||(144/987 MB:  14.67 %)
# TRANSFERRING ||######..................................||(144/987 MB:  14.68 %)
# TRANSFERRING ||######..................................||(144/987 MB:  14.69 %)
# TRANSFERRING ||######..................................||(145/987 MB:  14.70 %)
# TRANSFERRING ||######..................................||(145/987 MB:  14.71 %)
# TRANSFERRING ||######..................................||(145/987 MB:  14.72 %)
# TRANSFERRING ||######..................................||(145/987 MB:  14.74 %)
# TRANSFERRING ||######..................................||(145/987 MB:  14.75 %)
# TRANSFERRING ||######..................................||(145/987 MB:  14.77 %)
# TRANSFERRING ||######..................................||(145/987 MB:  14.79 %)
# TRANSFERRING ||######..................................||(146/987 MB:  14.80 %)
# TRANSFERRING ||######..................................||(146/987 MB:  14.82 %)
# TRANSFERRING ||######..................................||(146/987 MB:  14.85 %)
# TRANSFERRING ||######..................................||(146/987 MB:  14.87 %)
# TRANSFERRING ||######..................................||(147/987 MB:  14.90 %)
# TRANSFERRING ||######..................................||(147/987 MB:  14.94 %)
# TRANSFERRING ||######..................................||(147/987 MB:  14.97 %)
# TRANSFERRING ||#######.................................||(148/987 MB:  15.03 %)
# TRANSFERRING ||#######.................................||(149/987 MB:  15.10 %)
# TRANSFERRING ||#######.................................||(149/987 MB:  15.18 %)
# TRANSFERRING ||#######.................................||(150/987 MB:  15.28 %)
# TRANSFERRING ||#######.................................||(151/987 MB:  15.38 %)
# TRANSFERRING ||#######.................................||(151/987 MB:  15.39 %)
# TRANSFERRING ||#######.................................||(152/987 MB:  15.40 %)
# TRANSFERRING ||#######.................................||(152/987 MB:  15.42 %)
# TRANSFERRING ||#######.................................||(152/987 MB:  15.43 %)
# TRANSFERRING ||#######.................................||(152/987 MB:  15.45 %)
# TRANSFERRING ||#######.................................||(152/987 MB:  15.45 %)
# TRANSFERRING ||#######.................................||(153/987 MB:  15.56 %)
# TRANSFERRING ||#######.................................||(155/987 MB:  15.75 %)
# TRANSFERRING ||#######.................................||(156/987 MB:  15.89 %)
# TRANSFERRING ||#######.................................||(161/987 MB:  16.39 %)
# TRANSFERRING ||#######.................................||(164/987 MB:  16.66 %)
# TRANSFERRING ||#######.................................||(167/987 MB:  17.00 %)
# TRANSFERRING ||#######.................................||(168/987 MB:  17.08 %)
# TRANSFERRING ||#######.................................||(170/987 MB:  17.28 %)
# TRANSFERRING ||#######.................................||(170/987 MB:  17.31 %)
# TRANSFERRING ||#######.................................||(170/987 MB:  17.32 %)
# TRANSFERRING ||#######.................................||(171/987 MB:  17.33 %)
# TRANSFERRING ||#######.................................||(171/987 MB:  17.34 %)
# TRANSFERRING ||#######.................................||(171/987 MB:  17.35 %)
# TRANSFERRING ||########................................||(174/987 MB:  17.68 %)
# TRANSFERRING ||########................................||(178/987 MB:  18.05 %)
# TRANSFERRING ||########................................||(182/987 MB:  18.50 %)
# TRANSFERRING ||########................................||(186/987 MB:  18.89 %)
# TRANSFERRING ||########................................||(188/987 MB:  19.07 %)
# TRANSFERRING ||########................................||(189/987 MB:  19.19 %)
# TRANSFERRING ||########................................||(189/987 MB:  19.20 %)
# TRANSFERRING ||########................................||(189/987 MB:  19.22 %)
# TRANSFERRING ||########................................||(189/987 MB:  19.23 %)
# TRANSFERRING ||########................................||(189/987 MB:  19.24 %)
# TRANSFERRING ||########................................||(189/987 MB:  19.25 %)
# TRANSFERRING ||########................................||(190/987 MB:  19.26 %)
# TRANSFERRING ||########................................||(190/987 MB:  19.27 %)
# TRANSFERRING ||########................................||(190/987 MB:  19.29 %)
# ...
# TRANSFERRING ||#####################################...||(908/987 MB:  92.01 %)
# TRANSFERRING ||#####################################...||(908/987 MB:  92.04 %)
# TRANSFERRING ||#####################################...||(910/987 MB:  92.26 %)
# TRANSFERRING ||#####################################...||(911/987 MB:  92.38 %)
# TRANSFERRING ||#####################################...||(912/987 MB:  92.45 %)
# TRANSFERRING ||#####################################...||(912/987 MB:  92.48 %)
# TRANSFERRING ||######################################..||(915/987 MB:  92.80 %)
# TRANSFERRING ||######################################..||(917/987 MB:  92.96 %)
# TRANSFERRING ||######################################..||(917/987 MB:  92.99 %)
# TRANSFERRING ||######################################..||(918/987 MB:  93.01 %)
# TRANSFERRING ||######################################..||(918/987 MB:  93.04 %)
# TRANSFERRING ||######################################..||(919/987 MB:  93.13 %)
# TRANSFERRING ||######################################..||(921/987 MB:  93.39 %)
# TRANSFERRING ||######################################..||(922/987 MB:  93.47 %)
# TRANSFERRING ||######################################..||(923/987 MB:  93.58 %)
# TRANSFERRING ||######################################..||(923/987 MB:  93.60 %)
# TRANSFERRING ||######################################..||(924/987 MB:  93.62 %)
# TRANSFERRING ||######################################..||(924/987 MB:  93.64 %)
# TRANSFERRING ||######################################..||(924/987 MB:  93.66 %)
# TRANSFERRING ||######################################..||(924/987 MB:  93.69 %)
# TRANSFERRING ||######################################..||(924/987 MB:  93.71 %)
# TRANSFERRING ||######################################..||(925/987 MB:  93.73 %)
# TRANSFERRING ||######################################..||(925/987 MB:  93.75 %)
# TRANSFERRING ||######################################..||(925/987 MB:  93.76 %)
# TRANSFERRING ||######################################..||(925/987 MB:  93.76 %)
# TRANSFERRING ||######################################..||(925/987 MB:  93.77 %)
# TRANSFERRING ||######################################..||(925/987 MB:  93.78 %)
# TRANSFERRING ||######################################..||(925/987 MB:  93.79 %)
# TRANSFERRING ||######################################..||(925/987 MB:  93.80 %)
# TRANSFERRING ||######################################..||(925/987 MB:  93.81 %)
# TRANSFERRING ||######################################..||(926/987 MB:  93.82 %)
# TRANSFERRING ||######################################..||(926/987 MB:  93.84 %)
# TRANSFERRING ||######################################..||(926/987 MB:  93.86 %)
# TRANSFERRING ||######################################..||(926/987 MB:  93.88 %)
# TRANSFERRING ||######################################..||(926/987 MB:  93.91 %)
# TRANSFERRING ||######################################..||(927/987 MB:  93.93 %)
# TRANSFERRING ||######################################..||(927/987 MB:  93.95 %)
# TRANSFERRING ||######################################..||(927/987 MB:  93.97 %)
# TRANSFERRING ||######################################..||(927/987 MB:  93.99 %)
# TRANSFERRING ||######################################..||(927/987 MB:  94.01 %)
# TRANSFERRING ||######################################..||(928/987 MB:  94.03 %)
# TRANSFERRING ||######################################..||(928/987 MB:  94.05 %)
# TRANSFERRING ||#####################################...||(906/987 MB:  91.85 %)
# TRANSFERRING ||######################################..||(928/987 MB:  94.09 %)
# TRANSFERRING ||######################################..||(928/987 MB:  94.10 %)
# TRANSFERRING ||######################################..||(930/987 MB:  94.28 %)
# TRANSFERRING ||######################################..||(932/987 MB:  94.43 %)
# TRANSFERRING ||######################################..||(933/987 MB:  94.56 %)
# TRANSFERRING ||######################################..||(933/987 MB:  94.60 %)
# TRANSFERRING ||######################################..||(933/987 MB:  94.61 %)
# TRANSFERRING ||######################################..||(933/987 MB:  94.62 %)
# TRANSFERRING ||######################################..||(934/987 MB:  94.64 %)
# TRANSFERRING ||######################################..||(935/987 MB:  94.80 %)
# TRANSFERRING ||######################################..||(937/987 MB:  94.98 %)
# TRANSFERRING ||#######################################.||(938/987 MB:  95.12 %)
# TRANSFERRING ||#######################################.||(939/987 MB:  95.16 %)
# TRANSFERRING ||#######################################.||(939/987 MB:  95.19 %)
# TRANSFERRING ||#######################################.||(939/987 MB:  95.20 %)
# TRANSFERRING ||#######################################.||(939/987 MB:  95.22 %)
# TRANSFERRING ||#######################################.||(940/987 MB:  95.24 %)
# TRANSFERRING ||#######################################.||(940/987 MB:  95.26 %)
# TRANSFERRING ||#######################################.||(940/987 MB:  95.27 %)
# TRANSFERRING ||#######################################.||(940/987 MB:  95.29 %)
# TRANSFERRING ||#######################################.||(940/987 MB:  95.30 %)
# TRANSFERRING ||#######################################.||(940/987 MB:  95.31 %)
# TRANSFERRING ||#######################################.||(940/987 MB:  95.32 %)
# TRANSFERRING ||#######################################.||(941/987 MB:  95.34 %)
# TRANSFERRING ||#######################################.||(941/987 MB:  95.36 %)
# TRANSFERRING ||#######################################.||(941/987 MB:  95.38 %)
# TRANSFERRING ||#######################################.||(941/987 MB:  95.39 %)
# TRANSFERRING ||#######################################.||(941/987 MB:  95.41 %)
# TRANSFERRING ||#######################################.||(941/987 MB:  95.43 %)
# TRANSFERRING ||#######################################.||(942/987 MB:  95.44 %)
# TRANSFERRING ||#######################################.||(942/987 MB:  95.45 %)
# TRANSFERRING ||#######################################.||(942/987 MB:  95.46 %)
# TRANSFERRING ||#######################################.||(942/987 MB:  95.47 %)
# TRANSFERRING ||#######################################.||(942/987 MB:  95.48 %)
# TRANSFERRING ||#######################################.||(942/987 MB:  95.49 %)
# TRANSFERRING ||#######################################.||(942/987 MB:  95.50 %)
# TRANSFERRING ||#######################################.||(942/987 MB:  95.51 %)
# TRANSFERRING ||#######################################.||(942/987 MB:  95.52 %)
# TRANSFERRING ||#######################################.||(943/987 MB:  95.54 %)
# TRANSFERRING ||#######################################.||(943/987 MB:  95.56 %)
# TRANSFERRING ||#######################################.||(943/987 MB:  95.59 %)
# TRANSFERRING ||#######################################.||(943/987 MB:  95.61 %)
# TRANSFERRING ||#######################################.||(943/987 MB:  95.64 %)
# TRANSFERRING ||#######################################.||(944/987 MB:  95.66 %)
# TRANSFERRING ||#######################################.||(944/987 MB:  95.69 %)
# TRANSFERRING ||#######################################.||(944/987 MB:  95.71 %)
# TRANSFERRING ||#######################################.||(945/987 MB:  95.74 %)
# TRANSFERRING ||#######################################.||(945/987 MB:  95.77 %)
# TRANSFERRING ||#######################################.||(945/987 MB:  95.79 %)
# TRANSFERRING ||#######################################.||(945/987 MB:  95.82 %)
# TRANSFERRING ||#######################################.||(946/987 MB:  95.85 %)
# TRANSFERRING ||#######################################.||(946/987 MB:  95.86 %)
# TRANSFERRING ||#######################################.||(946/987 MB:  95.88 %)
# TRANSFERRING ||#######################################.||(946/987 MB:  95.89 %)
# TRANSFERRING ||#######################################.||(946/987 MB:  95.91 %)
# TRANSFERRING ||#######################################.||(946/987 MB:  95.91 %)
# TRANSFERRING ||#######################################.||(946/987 MB:  95.91 %)
# TRANSFERRING ||#######################################.||(946/987 MB:  95.93 %)
# TRANSFERRING ||#######################################.||(947/987 MB:  96.01 %)
# TRANSFERRING ||#######################################.||(950/987 MB:  96.34 %)
# TRANSFERRING ||#######################################.||(952/987 MB:  96.50 %)
# TRANSFERRING ||#######################################.||(953/987 MB:  96.62 %)
# TRANSFERRING ||#######################################.||(954/987 MB:  96.70 %)
# TRANSFERRING ||#######################################.||(956/987 MB:  96.87 %)
# TRANSFERRING ||#######################################.||(957/987 MB:  96.97 %)
# TRANSFERRING ||#######################################.||(957/987 MB:  96.99 %)
# TRANSFERRING ||#######################################.||(957/987 MB:  97.01 %)
# TRANSFERRING ||#######################################.||(957/987 MB:  97.04 %)
# TRANSFERRING ||#######################################.||(961/987 MB:  97.37 %)
# TRANSFERRING ||########################################||(962/987 MB:  97.54 %)
# TRANSFERRING ||########################################||(963/987 MB:  97.64 %)
# TRANSFERRING ||########################################||(964/987 MB:  97.72 %)
# TRANSFERRING ||########################################||(966/987 MB:  97.94 %)
# TRANSFERRING ||########################################||(968/987 MB:  98.08 %)
# TRANSFERRING ||########################################||(968/987 MB:  98.11 %)
# TRANSFERRING ||########################################||(968/987 MB:  98.14 %)
# TRANSFERRING ||########################################||(968/987 MB:  98.16 %)
# TRANSFERRING ||########################################||(969/987 MB:  98.18 %)
# TRANSFERRING ||########################################||(969/987 MB:  98.20 %)
# TRANSFERRING ||########################################||(969/987 MB:  98.21 %)
# TRANSFERRING ||########################################||(969/987 MB:  98.22 %)
# TRANSFERRING ||########################################||(969/987 MB:  98.24 %)
# TRANSFERRING ||########################################||(969/987 MB:  98.25 %)
# TRANSFERRING ||########################################||(969/987 MB:  98.27 %)
# TRANSFERRING ||########################################||(970/987 MB:  98.28 %)
# TRANSFERRING ||########################################||(970/987 MB:  98.29 %)
# TRANSFERRING ||########################################||(970/987 MB:  98.30 %)
# TRANSFERRING ||########################################||(970/987 MB:  98.31 %)
# TRANSFERRING ||########################################||(970/987 MB:  98.33 %)
# TRANSFERRING ||########################################||(970/987 MB:  98.35 %)
# TRANSFERRING ||########################################||(971/987 MB:  98.38 %)
# TRANSFERRING ||########################################||(971/987 MB:  98.41 %)
# TRANSFERRING ||########################################||(971/987 MB:  98.43 %)
# TRANSFERRING ||########################################||(971/987 MB:  98.46 %)
# TRANSFERRING ||#######################################.||(950/987 MB:  96.26 %)
# TRANSFERRING ||########################################||(972/987 MB:  98.50 %)
# TRANSFERRING ||########################################||(972/987 MB:  98.51 %)
# TRANSFERRING ||########################################||(972/987 MB:  98.53 %)
# TRANSFERRING ||########################################||(974/987 MB:  98.76 %)
# TRANSFERRING ||########################################||(975/987 MB:  98.86 %)
# TRANSFERRING ||########################################||(976/987 MB:  98.91 %)
# TRANSFERRING ||########################################||(977/987 MB:  99.05 %)
# TRANSFERRING ||########################################||(977/987 MB:  99.08 %)
# TRANSFERRING ||########################################||(978/987 MB:  99.10 %)
# TRANSFERRING ||########################################||(978/987 MB:  99.13 %)
# TRANSFERRING ||########################################||(978/987 MB:  99.18 %)
# TRANSFERRING ||########################################||(979/987 MB:  99.23 %)
# TRANSFERRING ||########################################||(979/987 MB:  99.25 %)
# TRANSFERRING ||########################################||(979/987 MB:  99.28 %)
# TRANSFERRING ||########################################||(980/987 MB:  99.30 %)
# TRANSFERRING ||########################################||(980/987 MB:  99.32 %)
# TRANSFERRING ||########################################||(980/987 MB:  99.35 %)
# TRANSFERRING ||########################################||(980/987 MB:  99.38 %)
# TRANSFERRING ||########################################||(981/987 MB:  99.41 %)
# TRANSFERRING ||########################################||(981/987 MB:  99.44 %)
# TRANSFERRING ||########################################||(981/987 MB:  99.47 %)
# TRANSFERRING ||########################################||(982/987 MB:  99.49 %)
# TRANSFERRING ||########################################||(982/987 MB:  99.52 %)
# TRANSFERRING ||########################################||(982/987 MB:  99.55 %)
# TRANSFERRING ||########################################||(982/987 MB:  99.56 %)
# TRANSFERRING ||########################################||(982/987 MB:  99.57 %)
# TRANSFERRING ||########################################||(982/987 MB:  99.59 %)
# TRANSFERRING ||########################################||(983/987 MB:  99.59 %)
# TRANSFERRING ||########################################||(983/987 MB:  99.60 %)
# TRANSFERRING ||########################################||(983/987 MB:  99.61 %)
# TRANSFERRING ||########################################||(983/987 MB:  99.62 %)
# TRANSFERRING ||########################################||(983/987 MB:  99.63 %)
# TRANSFERRING ||########################################||(983/987 MB:  99.64 %)
# TRANSFERRING ||########################################||(983/987 MB:  99.66 %)
# TRANSFERRING ||########################################||(983/987 MB:  99.69 %)
# TRANSFERRING ||########################################||(984/987 MB:  99.72 %)
# TRANSFERRING ||########################################||(984/987 MB:  99.74 %)
# TRANSFERRING ||########################################||(984/987 MB:  99.75 %)
# TRANSFERRING ||########################################||(984/987 MB:  99.76 %)
# TRANSFERRING ||########################################||(984/987 MB:  99.77 %)
# TRANSFERRING ||########################################||(984/987 MB:  99.78 %)
# TRANSFERRING ||########################################||(985/987 MB:  99.79 %)
# TRANSFERRING ||########################################||(985/987 MB:  99.80 %)
# TRANSFERRING ||########################################||(985/987 MB:  99.81 %)
# TRANSFERRING ||########################################||(985/987 MB:  99.83 %)
# TRANSFERRING ||########################################||(985/987 MB:  99.83 %)
# TRANSFERRING ||########################################||(984/987 MB:  99.75 %)
# TRANSFERRING ||########################################||(984/987 MB:  99.75 %)
# TRANSFERRING ||########################################||(984/987 MB:  99.75 %)
# TRANSFERRING ||########################################||(984/987 MB:  99.75 %)
# TRANSFERRING ||########################################||(985/987 MB:  99.82 %)
# TRANSFERRING ||########################################||(985/987 MB:  99.83 %)
# TRANSFERRING ||########################################||(985/987 MB:  99.84 %)
# TRANSFERRING ||########################################||(985/987 MB:  99.87 %)
# TRANSFERRING ||########################################||(985/987 MB:  99.88 %)
# TRANSFERRING ||########################################||(986/987 MB:  99.90 %)
# TRANSFERRING ||########################################||(987/987 MB: 100.00 %)
# Download finished: /content/downloads/pixel-art-pinterest-020.zip
# TRANSFERRING ||########################################||(987/987 MB: 100.00 %)

# %% [markdown]
# # Fetch & Clone Repo
#
# Clone the `image-tagging-tools` repo as it has all the required utils and codes from preprocessing the image datasets to training the models and using them to classify the images.

# %%
# !git clone https://github.com/kk-digital/image-tagging-tools.git
# Out:
# Cloning into 'image-tagging-tools'...
# remote: Enumerating objects: 501, done.
# remote: Counting objects: 100% (225/225), done.
# remote: Compressing objects: 100% (148/148), done.
# remote: Total 501 (delta 124), reused 152 (delta 76), pack-reused 276
# Receiving objects: 100% (501/501), 6.67 MiB | 14.32 MiB/s, done.
# Resolving deltas: 100% (217/217), done.

# %% [markdown]
# # Preprocess the dataset images (Stage 1)
#
# Use the `image-dataset-processor` utils from the previously cloned repo to process a directory of images (paths to directory of images or an archived dataset), and computes the images metadata along with its CLIP embeddings and writes the result into a JSON file into `output_folder`

# %% [markdown]
# ### Install requirements

# %%
# %%capture
# %pip install ascii_graph open_clip_torch patool fire

# %% [markdown]
# ### Import the module/Utility

# %%
import sys
sys.path.insert(0, './image-tagging-tools/image-dataset-processor/')
sys.path.insert(0, './image-tagging-tools/')
from ImageDatasetProcessor import ImageDatasetProcessor
from classify import main as classify_main
from train import main as train_main
from classify_helper_functions import clean_file
import patoolib
import shutil


def is_archive(path: str) -> bool:
    """method to check if a given path is an archive.
    :param path: The file path to check. 
    :type path: str
    :returns: `True` if the given path is a path of an archived file. 
    :rtype: bool
    """
    
    try: 
        patoolib.get_archive_format(path)
        return True 
    except Exception: 
        return False 

def unzip_folder(folder_path :str):
    """takes an archived file path and unzip it.
    :param folder_path: path to the archived file.
    :type folder_path: str
    :returns: path of the new exracted folder 
    :rtype: str
    """
    dir_path  = os.path.dirname(folder_path)
    file_name = os.path.basename(folder_path).split('.zip')[0]
    os.makedirs(dir_path , exist_ok=True)
    
    print("[INFO] Extracting the archived file...")
    patoolib.extract_archive(folder_path, outdir=dir_path)
    print("[INFO] Extraction completed.")
    
    return latest_file(dir_path)

def clean_directory(
                    dir_path : str ,
                    only_sub_dir : bool = False
                    ):
    """ clean a directory files and folders

    :param dir_path: path to the directory which will be cleaned.
    :type dir_path: str
    :param only_sub_dir: an option to make it only sub directories 
                          for ex: in cleaning pixel-art-tagged folder.
    :type only_sub_dir: bool
    :rtype: None
    """
    for dir in os.listdir(dir_path):
      sub_dir = os.path.join(dir_path, dir)
      
      if os.path.isfile(sub_dir): # if it's a file then clean the file  
        if only_sub_dir: # no subfiles allowed for example in the pixel-art-tagged 
          os.remove(sub_dir)
          print(f"[Removing] {sub_dir}")
          continue 
        clean_file(sub_dir)
        continue

      if len(os.listdir(sub_dir)) == 0: # Empty folder, delte it 
        shutil.rmtree(sub_dir)
        #os.system(f'rm -r {sub_dir}') 
        print(f'[Removing] {sub_dir}')
        continue

      if os.path.isdir(sub_dir) and only_sub_dir: # move to the sub-directory and clean it.
        clean_directory(sub_dir)
      else:
        shutil.rmtree(sub_dir)

# %% [markdown]
# ### Unzipping and cleaning for the tagged images

# %%
if is_archive(tagged_dataset_path):
  tagged_images_folder = unzip_folder(tagged_dataset_path)
  clean_directory(tagged_images_folder, only_sub_dir=True)
# Out:
# [INFO] Extracting the archived file...
# patool: Extracting ./downloads/pixel-art-tagged-v2-merged-2022-11-22.zip ...
# patool: running /usr/bin/7z x -o./downloads -- ./downloads/pixel-art-tagged-v2-merged-2022-11-22.zip
# patool: ... ./downloads/pixel-art-tagged-v2-merged-2022-11-22.zip extracted to `./downloads'.
# [INFO] Extraction completed.
# [Removing] ./downloads/pixel-art-tagged-merged-2022-11-22/not-pixel-art/00006-32x32_100k_patches-mirror-auto1.zip
# [Warning] problem with ./downloads/pixel-art-tagged-merged-2022-11-22/other-validation/https___i.pinimg.com_originals_00_92_c4_0092c473456acd2e4819da18ac964760.gif, cannot identify image file './downloads/pixel-art-tagged-merged-2022-11-22/other-validation/https___i.pinimg.com_originals_00_92_c4_0092c473456acd2e4819da18ac964760.gif'
# [Warning] removing ./downloads/pixel-art-tagged-merged-2022-11-22/other-validation/https___i.pinimg.com_originals_00_92_c4_0092c473456acd2e4819da18ac964760.gif
# [Removing] ./downloads/pixel-art-tagged-merged-2022-11-22/note.txt

# %% [markdown]
# ### set required variables by the utility
#
# Initialize the required parameters needed by the dataset preprocessor utility and they are described as follows:
#
# * `input_folder` _[str]_ -  path to the directory containing sub-folders of each tag.
# * `output_folder` _[str]_ - path to the directory where to save the files into it.
#
# * `clip_model` _[str]_ - CLIP model to be used
#
# * `pretrained` _[str]_ - the pre-trained model to be used for CLIP
# * `batch_size` _[int]_ -  number of images to process at a time
# * `num_threads` _[int]_ - the number to be used in this process
#
# * `device` _[str]_ -  the device to be used in computing the CLIP embeddings, if `None` is provided then `cuda` will be used if available

# %%
dataset_path = tagged_images_folder
output_folder = "preprocess_output"
clip_model = "ViT-B-32"
pretrained = 'openai'
batch_size = 32
num_threads = 4
device = None

# %% [markdown]
# ### Run the Preprocessor

# %%
ImageDatasetProcessor.process_dataset(
    dataset_path, 
    output_folder, 
    clip_model, 
    pretrained,
    batch_size, 
    num_threads, 
    device
)
# Out:
# 100%|███████████████████████████████████████| 354M/354M [00:05<00:00, 63.7MiB/s]
# ['pos-environment-architecture', 'not-pixel-art', 'pos-style-synth-wave', 'pos-color-pallete', 'pos-pixel-art-scifi', 'pos-environmental-architecture', 'pos-pixel-art-character', 'other-validation', 'pos-environment', 'pos-pixel-art-tutorial', 'pos-pixel-art-environmental', 'pos-video-game-top-perspective', 'pos-video-game-isometric', 'pos-pixel-art-bad', 'pos-scifi', 'pos-environment-space', 'pos-pixel-art', 'pos-video-game-map', 'pos-pixel-art-best', 'pos-video-game-3d', 'not-pixel-art-digital', 'pos-pixel-art-texture', 'pos-style-comic', 'pos-sprite-sheet', 'pos-waifus', 'pos-character', 'pos-video-game', 'pos-environmental-natural', 'pos-video-game-flat', 'pos-machines', 'pos-video-game-style-miltech-kag', 'pos-environment-natural', 'pos-pixel-art-architecture', 'not-pixel-art-real-photo', 'pos-character-portrait', 'pos-video-game-side-scrolling', 'pos-video-game-top-down', 'pos-environmental-space', 'pos-style-tile-based', 'other-training', 'pos-pixel-art-space']
# [INFO] dataset pixel-art-tagged-merged-2022-11-22 finished processing 1000 images so far
# [INFO] dataset pixel-art-tagged-merged-2022-11-22 finished processing 2000 images so far
# [INFO] dataset pixel-art-tagged-merged-2022-11-22 finished processing 3000 images so far

# %% [markdown]
# ### Train script variables
#
#
# * `metadata_json` _[string]_ - _[required]_ - The path to the metadata json file.
# * `tag_to_hash_json` _[string]_ - _[required]_ - The path to tag-to-hash json file.
#
# * `output` _[string]_ - _[optional]_ - The path to the output directory.
# * `test_per` _[float]_ - _[optional]_ - The percentage of the test images from the dataset, default = 0.1

# %%
metadata_json = './preprocess_output/input-metadata.json' 
tag_to_hash_json = './preprocess_output/input-tag-to-image-hash-list.json'
output_dir = './models_reports'
test_per = 0.1

# %% [markdown]
# ### Run training script

# %%
train_main(
    metadata_json = metadata_json,
    tag_to_hash_json = tag_to_hash_json,
    output_dir = output_dir,
    test_per = test_per
)
# Out:
# [INFO] Finished.

# %% [markdown]
# ### Classification script variables
#
# * `directory` _[string]_ - _[required]_ - The path to the images' folder or images' .zip file.
# * `metadata_json` _[string]_ - _[required]_ - The path to the metadata json file for CLIP embeddings.
# * `output` _[string]_ - _[optional]_ - The path to the output directory for the inference results.
# * `model` _[string]_ - _[optional]_ - The path to the models' .pkl files directory or single .pkl file model.
# * `output_bins` _[int]_ - _[optional]_ -  The number of bins of the results for each model.

# %% [markdown]
# #### Classification fot other-validation folder (pre-computed CLIP embeddings)

# %%
folder_path    = os.path.join(tagged_images_folder,"other-validation")
output_dir     = "./classification_other_validation"
json_file_path =  "/content/preprocess_output/input-metadata.json"
bins_number    = 10
model_path     = "./models_reports/models"

# %%
classify_main(
        folder_path    = folder_path , 
        output_dir     = output_dir, 
        json_file_path = json_file_path, 
        bins_number    = bins_number , 
        model_path     = model_path, 
        )
# Out:
# [INFO] Output folder ./classification_other_validation
# 100%|██████████| 78/78 [00:00<00:00, 988.62it/s]
# 100%|██████████| 220/220 [00:31<00:00,  6.95it/s]
# [INFO] Finished.

# %% [markdown]
# #### Classifction for .zip file full of images (takes more time)

# %%
folder_path    = other_dataset_path
output_dir     = "./classification_other_folder"
json_file_path =  "/content/preprocess_output/input-metadata.json"
bins_number    = 10
model_path     = "./models_reports/models"

# %%
classify_main(
        folder_path    = folder_path , 
        output_dir     = output_dir, 
        json_file_path = json_file_path, 
        bins_number    = bins_number , 
        model_path     = model_path, 
        )
